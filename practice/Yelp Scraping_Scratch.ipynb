# %% [markdown]
# # Yelp

# %%
from selenium import webdriver
from time import sleep
ch_driver = webdriver.Chrome('C:/Users/beave/AppData/Roaming/Microsoft/Windows/Start Menu/Programs/Python 3.7/chromedriver.exe')

# %%
yelp_url = 'https://www.yelp.com/'
ch_driver.get(yelp_url)

# %%
search_input = ch_driver.find_element_by_id('find_desc')
search_input.send_keys('restaurants')
city_input = ch_driver.find_element_by_id('dropperText_Mast')
city_input.click()
city_input.send_keys('los angeles')

# %%
search_button = ch_driver.find_element_by_id('header-search-submit')
search_button.click()

# %%
r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
restaurants = ch_driver.find_elements_by_xpath(r_path)

# %%
len(restaurants)
# Out:
# 34

# %%
#get rank and name
rank_name = restaurants[0].find_element_by_tag_name('h3').text.strip("\n")
rank_name[0].isdigit()
# Out:
# False

# %%
rank = restaurants[4].find_element_by_tag_name('h3').text
rank[0].isdigit()
# Out:
# True

# %%
#get link
r_link = restaurants[0].find_element_by_tag_name('a').get_attribute('href')
r_link
# Out:
# 'https://www.yelp.com/adredir?ad_business_id=tEK23PiHNXBHzu8994jurg&campaign_id=lGn-maKsI8_MFr3IULJpKw&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Findias-tandoori-hollywood-los-angeles&request_id=0d9da8adf5eee286&signature=ca3cbf31056f676556308c9fc1a0b26c3093634bdff9cfa99bf185d9ea313a2a&slot=0'

# %%
#get rating
rating_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div'
rating = ch_driver.find_element_by_xpath(rating_path).get_attribute('aria-label')
rating
# Out:
# '4.5 star rating'

# %%
#get number of reviews
review_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span'
review_num = ch_driver.find_element_by_xpath(review_path).text
review_num
# Out:
# '5342 reviews'

# %%
#get price range
# price_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span[1]'
# price_index = ch_driver.find_element_by_xpath(price_path).text
# price_index

# %%
#get category
# cat_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span[2]'
# category = ch_driver.find_element_by_xpath(cat_path).text
# category

# %%
#price range& category
pc_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[2]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span'
price_cat = ch_driver.find_elements_by_xpath(pc_path)
print(price_cat[0].text)
print(price_cat[1].text)
# Out:
# $
# Tacos

# %%
price = price_cat[0].text
category = price_cat[1].text

# %%
print(price, category)
# Out:
# $$$ Italian, Cocktail Bars, Pizza

# %%
r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
restaurants = ch_driver.find_elements_by_xpath(r_path)
for i,item in enumerate(restaurants):
    title = item.find_element_by_tag_name('h3').text
    link = item.find_element_by_tag_name('a').get_attribute('href')
    
    #get rating
    rating_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                  str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div')
    rating = rating_elem.get_attribute('aria-label')
    #print(rating)
    
    #get number of reviews
    review_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li['
                                                  + str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span')
    review_num = review_elem.text
    
    #get price index and category
    try:
        pc_elem = ch_driver.find_elements_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                   str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
        price = pc_elem[0].text
        category = pc_elem[1].text
    except IndexError:
        pc_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                   str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
        price = "N/A"
        category = pc_elem.text
    
    
    print(title, link, rating, review_num, price, category, sep="\n")
    print('\n')
# Out:
# Ad
# Taco Nazo- Bellflower
# https://www.yelp.com/adredir?ad_business_id=zyRFrQo4-WUfEO-K2cRgkQ&campaign_id=DgnpkgqlHLyamy8IxlsJNw&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Ftaco-nazo-bellflower-bellflower&request_id=def102b8ae682d2f&signature=fe5ee1514844e21040c19c86a77bb4d9a542f568537a953ecd74a1df82e60f39&slot=0
# 4.5 star rating
# 2053 reviews
# $
# Tacos
#
#
# Ad
# India’s Tandoori Hollywood
# https://www.yelp.com/adredir?ad_business_id=tEK23PiHNXBHzu8994jurg&campaign_id=lGn-maKsI8_MFr3IULJpKw&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Findias-tandoori-hollywood-los-angeles&request_id=def102b8ae682d2f&signature=59665c960d8a93f4a41d36fafd37c0e771627e56ac7dc34a3b34f65b2c1b9a09&slot=1
# 4.5 star rating
# 36 reviews
# N/A
# Buffets, Indian, Halal
#
#
# Ad
# Taste of India - Sherman Oaks
# https://www.yelp.com/adredir?ad_business_id=7rio_T3BIJhmoOA3NiFasQ&campaign_id=HJwYYCZfNdkFUTskx4OlHQ&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Ftaste-of-india-sherman-oaks-sherman-oaks&request_id=def102b8ae682d2f&signature=3d738af437304ec9c6802ea56e10dffb6d4956a6364c453ba76d303f334704b2&slot=2
# 4 star rating
# 386 reviews
# $$
# Indian
#
#
# 1. Bestia
# https://www.yelp.com/biz/bestia-los-angeles?osq=restaurants
# 4.5 star rating
# 5342 reviews
# $$$
# Italian, Cocktail Bars, Pizza
#
#
# 2. Running Goose
# https://www.yelp.com/biz/running-goose-los-angeles?osq=restaurants
# 4.5 star rating
# 756 reviews
# $$
# Tapas/Small Plates, Gastropubs, Latin American
#
#
# 3. The Morrison
# https://www.yelp.com/biz/the-morrison-los-angeles?osq=restaurants
# 4.5 star rating
# 3897 reviews
# $$
# Gastropubs, Burgers, Bars
#
#
# 4. Howlin’ Ray’s
# https://www.yelp.com/biz/howlin-rays-los-angeles-3?osq=restaurants
# 4.5 star rating
# 4308 reviews
# $$
# Southern, Chicken Shop, American (Traditional)
#
#
# 5. RockSugar Southeast Asian Kitchen
# https://www.yelp.com/biz/rocksugar-southeast-asian-kitchen-los-angeles?osq=restaurants
# 4 star rating
# 2174 reviews
# $$
# Indonesian, Vietnamese, Malaysian
#
#
# 6. Bao Dim Sum House
# https://www.yelp.com/biz/bao-dim-sum-house-los-angeles?osq=restaurants
# 4 star rating
# 2402 reviews
# $$
# Dim Sum, Bars, Tapas/Small Plates
#
#
# 7. Perch
# https://www.yelp.com/biz/perch-los-angeles?osq=restaurants
# 4 star rating
# 6374 reviews
# $$$
# Lounges, French
#
#
# 8. Daikokuya Little Tokyo
# https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?osq=restaurants
# 4 star rating
# 7858 reviews
# $$
# Ramen, Noodles
#
#
# 9. Eataly
# https://www.yelp.com/biz/eataly-los-angeles-6?osq=restaurants
# 3.5 star rating
# 1524 reviews
# $$
# Specialty Food, Italian, Food Court
#
#
# 10. République
# https://www.yelp.com/biz/r%C3%A9publique-los-angeles-2?osq=restaurants
# 4 star rating
# 4447 reviews
# $$
# French, Breakfast & Brunch, Cocktail Bars
#
#
# 11. Myungrang Hot Dog-California Market LA
# https://www.yelp.com/biz/myungrang-hot-dog-california-market-la-los-angeles?osq=restaurants
# 4 star rating
# 38 reviews
# N/A
# Hot Dogs
#
#
# 12. Din Tai Fung
# https://www.yelp.com/biz/din-tai-fung-los-angeles?osq=restaurants
# 4 star rating
# 557 reviews
# $$
# Taiwanese, Chinese
#
#
# 13. Franco’s
# https://www.yelp.com/biz/francos-los-angeles?osq=restaurants
# 4 star rating
# 1094 reviews
# $$
# Italian, Steakhouses, Seafood
#
#
# 14. Genwa Korean BBQ
# https://www.yelp.com/biz/genwa-korean-bbq-los-angeles-2?osq=restaurants
# 4.5 star rating
# 2650 reviews
# $$
# Korean, Barbeque, Soup
#
#
# 15. Marugame Monzo
# https://www.yelp.com/biz/marugame-monzo-los-angeles-2?osq=restaurants
# 4.5 star rating
# 3143 reviews
# $$
# Japanese, Noodles, Asian Fusion
#
#
# 16. A Food Affair
# https://www.yelp.com/biz/a-food-affair-los-angeles?osq=restaurants
# 4.5 star rating
# 1126 reviews
# $$
# French, American (New)
#
#
# 17. Slurpin’ Ramen Bar
# https://www.yelp.com/biz/slurpin-ramen-bar-los-angeles?osq=restaurants
# 4.5 star rating
# 3169 reviews
# $$
# Ramen, Noodles
#
#
# 18. The Little Door
# https://www.yelp.com/biz/the-little-door-los-angeles?osq=restaurants
# 4 star rating
# 1918 reviews
# $$$
# French, Mediterranean, Modern European
#
#
# 19. Wurstküche
# https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?osq=restaurants
# 4 star rating
# 7913 reviews
# $$
# Hot Dogs, German, Gastropubs
#
#
# 20. Dirt Dog
# https://www.yelp.com/biz/dirt-dog-los-angeles-4?osq=restaurants
# 4.5 star rating
# 1509 reviews
# $
# Hot Dogs, Beer Bar
#
#
# 21. Osteria Mamma
# https://www.yelp.com/biz/osteria-mamma-los-angeles?osq=restaurants
# 4 star rating
# 1386 reviews
# $$
# Italian, Wine Bars
#
#
# 22. Kang Ho-dong Baekjeong
# https://www.yelp.com/biz/kang-ho-dong-baekjeong-los-angeles-4?osq=restaurants
# 4.5 star rating
# 3897 reviews
# $$
# Barbeque, Korean
#
#
# 23. COD Restaurant
# https://www.yelp.com/biz/cod-restaurant-los-angeles?osq=restaurants
# 4.5 star rating
# 538 reviews
# $$$
# Seafood, Live/Raw Food, Asian Fusion
#
#
# 24. Maccheroni Republic
# https://www.yelp.com/biz/maccheroni-republic-los-angeles?osq=restaurants
# 4 star rating
# 2393 reviews
# $$
# Italian, Wine Bars
#
#
# 25. Sage Vegan Bistro - Echo Park
# https://www.yelp.com/biz/sage-vegan-bistro-echo-park-los-angeles-3?osq=restaurants
# 4 star rating
# 1921 reviews
# $$
# Vegan, Brewpubs
#
#
# 26. Bottega Louie
# https://www.yelp.com/biz/bottega-louie-los-angeles?osq=restaurants
# 4 star rating
# 15796 reviews
# $$
# Italian, Bakeries, Breakfast & Brunch
#
#
# 27. Chinchikurin-Sawtelle
# https://www.yelp.com/biz/chinchikurin-sawtelle-los-angeles?osq=restaurants
# 4.5 star rating
# 404 reviews
# $$
# Japanese
#
#
# 28. The Parker Room
# https://www.yelp.com/biz/the-parker-room-los-angeles?osq=restaurants
# 4.5 star rating
# 148 reviews
# $$
# American (Traditional), Lounges
#
#
# 29. Shojin Downtown
# https://www.yelp.com/biz/shojin-downtown-los-angeles?osq=restaurants
# 4 star rating
# 1632 reviews
# $$
# Japanese, Vegan, Gluten-Free
#
#
# 30. Guelaguetza Restaurante
# https://www.yelp.com/biz/guelaguetza-restaurante-los-angeles?osq=restaurants
# 4 star rating
# 1797 reviews
# $$
# Mexican
#
#
# Ad
# Electric Karma
# https://www.yelp.com/adredir?ad_business_id=84PmY6fwOx9Z33aX3sb_GQ&campaign_id=IphTK-ekafYWEZJsH6-M3Q&click_origin=search_results&placement=below_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Felectric-karma-los-angeles&request_id=def102b8ae682d2f&signature=afe18b152003367192fca79ca7dad4edc71678493bb989867bcf2575b747eda2&slot=0
# 4 star rating
# 749 reviews
# $$
# Indian

# %%
# def get_restaurants():
#     result = []
#     r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
#     restaurants = ch_driver.find_elements_by_xpath(r_path)
#     for i,item in enumerate(restaurants):
#         title = item.find_element_by_tag_name('h3').text
#         link = item.find_element_by_tag_name('a').get_attribute('href')

#         #get rating
#         rating_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                       str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div')
#         rating = rating_elem.get_attribute('aria-label')
#         #print(rating)

#         #get number of reviews
#         review_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li['
#                                                       + str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span')
#         review_num = review_elem.text

#         #get price index and category
#         try:
#             pc_elem = ch_driver.find_elements_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                        str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
#             price = pc_elem[0].text
#             category = pc_elem[1].text
#         except IndexError:
#             pc_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                        str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
#             price = "N/A"
#             category = pc_elem.text
        
#         #전체 var 받은뒤 title로 광고 게시물 거르기
#         if title[0].isdigit() == False:
#             continue
            
#         result.append((title, link, rating, review_num, price, category))
#     return result

# %%
# get_restaurants()
# Out:
# [('1. Bestia',
#   'https://www.yelp.com/biz/bestia-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '5343 reviews',
#   '$$$',
#   'Italian, Cocktail Bars, Pizza'),
#  ('2. Howlin’ Ray’s',
#   'https://www.yelp.com/biz/howlin-rays-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '4312 reviews',
#   '$$',
#   'Southern, Chicken Shop, American (Traditional)'),
#  ('3. Running Goose',
#   'https://www.yelp.com/biz/running-goose-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '757 reviews',
#   '$$',
#   'Tapas/Small Plates, Gastropubs, Latin American'),
#  ('4. République',
#   'https://www.yelp.com/biz/r%C3%A9publique-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '4452 reviews',
#   '$$',
#   'French, Breakfast & Brunch, Cocktail Bars'),
#  ('5. RockSugar Southeast Asian Kitchen',
#   'https://www.yelp.com/biz/rocksugar-southeast-asian-kitchen-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2177 reviews',
#   '$$',
#   'Indonesian, Vietnamese, Malaysian'),
#  ('6. The Morrison',
#   'https://www.yelp.com/biz/the-morrison-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3897 reviews',
#   '$$',
#   'Gastropubs, Burgers, Bars'),
#  ('7. Slurpin’ Ramen Bar',
#   'https://www.yelp.com/biz/slurpin-ramen-bar-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3172 reviews',
#   '$$',
#   'Ramen, Noodles'),
#  ('8. Bao Dim Sum House',
#   'https://www.yelp.com/biz/bao-dim-sum-house-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2402 reviews',
#   '$$',
#   'Dim Sum, Bars, Tapas/Small Plates'),
#  ('9. Daikokuya Little Tokyo',
#   'https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?osq=restaurants',
#   '4 star rating',
#   '7858 reviews',
#   '$$',
#   'Ramen, Noodles'),
#  ('10. Dirt Dog',
#   'https://www.yelp.com/biz/dirt-dog-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1511 reviews',
#   '$',
#   'Hot Dogs, Beer Bar'),
#  ('11. Perch',
#   'https://www.yelp.com/biz/perch-los-angeles?osq=restaurants',
#   '4 star rating',
#   '6379 reviews',
#   '$$$',
#   'Lounges, French'),
#  ('12. Yup Dduk La',
#   'https://www.yelp.com/biz/yup-dduk-la-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1761 reviews',
#   '$$',
#   'Korean'),
#  ('13. Han Bat Shul Lung Tang',
#   'https://www.yelp.com/biz/han-bat-shul-lung-tang-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1906 reviews',
#   '$',
#   'Korean, Comfort Food, Soup'),
#  ('14. Marugame Monzo',
#   'https://www.yelp.com/biz/marugame-monzo-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '3148 reviews',
#   '$$',
#   'Japanese, Noodles, Asian Fusion'),
#  ('15. Genwa Korean BBQ',
#   'https://www.yelp.com/biz/genwa-korean-bbq-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '2652 reviews',
#   '$$',
#   'Korean, Barbeque, Soup'),
#  ('16. Kang Ho-dong Baekjeong',
#   'https://www.yelp.com/biz/kang-ho-dong-baekjeong-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '3898 reviews',
#   '$$',
#   'Barbeque, Korean'),
#  ('17. Eggslut',
#   'https://www.yelp.com/biz/eggslut-los-angeles-7?osq=restaurants',
#   '4 star rating',
#   '5263 reviews',
#   '$',
#   'Breakfast & Brunch'),
#  ('18. Bottega Louie',
#   'https://www.yelp.com/biz/bottega-louie-los-angeles?osq=restaurants',
#   '4 star rating',
#   '15801 reviews',
#   '$$',
#   'Italian, Bakeries, Breakfast & Brunch'),
#  ('19. Eataly',
#   'https://www.yelp.com/biz/eataly-los-angeles-6?osq=restaurants',
#   '3.5 star rating',
#   '1530 reviews',
#   '$$',
#   'Specialty Food, Italian, Food Court'),
#  ('20. Pasta Sisters',
#   'https://www.yelp.com/biz/pasta-sisters-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1117 reviews',
#   '$$',
#   'Delis, Italian'),
#  ('21. The Little Door',
#   'https://www.yelp.com/biz/the-little-door-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1918 reviews',
#   '$$$',
#   'French, Mediterranean, Modern European'),
#  ('22. Dave’s Hot Chicken',
#   'https://www.yelp.com/biz/daves-hot-chicken-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1203 reviews',
#   '$$',
#   'Chicken Shop'),
#  ('23. Corn Man',
#   'https://www.yelp.com/biz/corn-man-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '816 reviews',
#   '$',
#   'Food Stands, Mexican'),
#  ('24. Wurstküche',
#   'https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '7913 reviews',
#   '$$',
#   'Hot Dogs, German, Gastropubs'),
#  ('25. Sun Nong Dan',
#   'https://www.yelp.com/biz/sun-nong-dan-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1163 reviews',
#   '$$',
#   'Korean, Soup'),
#  ('26. Osteria Mamma',
#   'https://www.yelp.com/biz/osteria-mamma-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1386 reviews',
#   '$$',
#   'Italian, Wine Bars'),
#  ('27. Myungrang Hot Dog-California Market LA',
#   'https://www.yelp.com/biz/myungrang-hot-dog-california-market-la-los-angeles?osq=restaurants',
#   '4 star rating',
#   '43 reviews',
#   'N/A',
#   'Hot Dogs'),
#  ('28. Hangari Bajirak Kalguksu',
#   'https://www.yelp.com/biz/hangari-bajirak-kalguksu-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1296 reviews',
#   '$$',
#   'Korean, Soup, Noodles'),
#  ('29. L’Assiette Steak Frites',
#   'https://www.yelp.com/biz/l-assiette-steak-frites-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '623 reviews',
#   '$$',
#   'Steakhouses, French, Wine Bars'),
#  ('30. Franco’s',
#   'https://www.yelp.com/biz/francos-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1094 reviews',
#   '$$',
#   'Italian, Steakhouses, Seafood')]

# %% [markdown]
# ## title을 key, 나머지를 value로 해서 result dict에 넣기

# %%
# #result를 list로 만들기
# def get_restaurant_list():
#     result_list = []
   
#     r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
#     restaurants = ch_driver.find_elements_by_xpath(r_path)
#     for i,item in enumerate(restaurants):
#         title = item.find_element_by_tag_name('h3').text
#         link = item.find_element_by_tag_name('a').get_attribute('href')

#         #get rating
#         rating_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                       str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div')
#         rating = rating_elem.get_attribute('aria-label')
#         #print(rating)

#         #get number of reviews
#         review_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li['
#                                                       + str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span')
#         review_num = review_elem.text

#         #get price index and category
#         try:
#             pc_elem = ch_driver.find_elements_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                        str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
#             price = pc_elem[0].text
#             category = pc_elem[1].text
#         except IndexError:
#             pc_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
#                                                        str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
#             price = "N/A"
#             category = pc_elem.text
        
#         #전체 var 받은뒤 title로 광고 게시물 거르기
#         if title[0].isdigit() == False:
#             continue
            
#         result_list.append([title, link, rating, review_num, price, category])
    
 
        
#     return result_list

# %%
# get_restaurant_list()
# Out:
# [['1. Bestia',
#   'https://www.yelp.com/biz/bestia-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '5343 reviews',
#   '$$$',
#   'Italian, Cocktail Bars, Pizza'],
#  ['2. Howlin’ Ray’s',
#   'https://www.yelp.com/biz/howlin-rays-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '4312 reviews',
#   '$$',
#   'Southern, Chicken Shop, American (Traditional)'],
#  ['3. Running Goose',
#   'https://www.yelp.com/biz/running-goose-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '757 reviews',
#   '$$',
#   'Tapas/Small Plates, Gastropubs, Latin American'],
#  ['4. République',
#   'https://www.yelp.com/biz/r%C3%A9publique-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '4452 reviews',
#   '$$',
#   'French, Breakfast & Brunch, Cocktail Bars'],
#  ['5. RockSugar Southeast Asian Kitchen',
#   'https://www.yelp.com/biz/rocksugar-southeast-asian-kitchen-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2177 reviews',
#   '$$',
#   'Indonesian, Vietnamese, Malaysian'],
#  ['6. The Morrison',
#   'https://www.yelp.com/biz/the-morrison-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3897 reviews',
#   '$$',
#   'Gastropubs, Burgers, Bars'],
#  ['7. Slurpin’ Ramen Bar',
#   'https://www.yelp.com/biz/slurpin-ramen-bar-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3172 reviews',
#   '$$',
#   'Ramen, Noodles'],
#  ['8. Bao Dim Sum House',
#   'https://www.yelp.com/biz/bao-dim-sum-house-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2402 reviews',
#   '$$',
#   'Dim Sum, Bars, Tapas/Small Plates'],
#  ['9. Daikokuya Little Tokyo',
#   'https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?osq=restaurants',
#   '4 star rating',
#   '7858 reviews',
#   '$$',
#   'Ramen, Noodles'],
#  ['10. Dirt Dog',
#   'https://www.yelp.com/biz/dirt-dog-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1511 reviews',
#   '$',
#   'Hot Dogs, Beer Bar'],
#  ['11. Perch',
#   'https://www.yelp.com/biz/perch-los-angeles?osq=restaurants',
#   '4 star rating',
#   '6379 reviews',
#   '$$$',
#   'Lounges, French'],
#  ['12. Yup Dduk La',
#   'https://www.yelp.com/biz/yup-dduk-la-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1761 reviews',
#   '$$',
#   'Korean'],
#  ['13. Han Bat Shul Lung Tang',
#   'https://www.yelp.com/biz/han-bat-shul-lung-tang-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1906 reviews',
#   '$',
#   'Korean, Comfort Food, Soup'],
#  ['14. Marugame Monzo',
#   'https://www.yelp.com/biz/marugame-monzo-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '3148 reviews',
#   '$$',
#   'Japanese, Noodles, Asian Fusion'],
#  ['15. Genwa Korean BBQ',
#   'https://www.yelp.com/biz/genwa-korean-bbq-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '2652 reviews',
#   '$$',
#   'Korean, Barbeque, Soup'],
#  ['16. Kang Ho-dong Baekjeong',
#   'https://www.yelp.com/biz/kang-ho-dong-baekjeong-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '3898 reviews',
#   '$$',
#   'Barbeque, Korean'],
#  ['17. Eggslut',
#   'https://www.yelp.com/biz/eggslut-los-angeles-7?osq=restaurants',
#   '4 star rating',
#   '5263 reviews',
#   '$',
#   'Breakfast & Brunch'],
#  ['18. Bottega Louie',
#   'https://www.yelp.com/biz/bottega-louie-los-angeles?osq=restaurants',
#   '4 star rating',
#   '15801 reviews',
#   '$$',
#   'Italian, Bakeries, Breakfast & Brunch'],
#  ['19. Eataly',
#   'https://www.yelp.com/biz/eataly-los-angeles-6?osq=restaurants',
#   '3.5 star rating',
#   '1530 reviews',
#   '$$',
#   'Specialty Food, Italian, Food Court'],
#  ['20. Pasta Sisters',
#   'https://www.yelp.com/biz/pasta-sisters-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1117 reviews',
#   '$$',
#   'Delis, Italian'],
#  ['21. The Little Door',
#   'https://www.yelp.com/biz/the-little-door-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1918 reviews',
#   '$$$',
#   'French, Mediterranean, Modern European'],
#  ['22. Dave’s Hot Chicken',
#   'https://www.yelp.com/biz/daves-hot-chicken-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1203 reviews',
#   '$$',
#   'Chicken Shop'],
#  ['23. Corn Man',
#   'https://www.yelp.com/biz/corn-man-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '816 reviews',
#   '$',
#   'Food Stands, Mexican'],
#  ['24. Wurstküche',
#   'https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '7913 reviews',
#   '$$',
#   'Hot Dogs, German, Gastropubs'],
#  ['25. Sun Nong Dan',
#   'https://www.yelp.com/biz/sun-nong-dan-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1163 reviews',
#   '$$',
#   'Korean, Soup'],
#  ['26. Osteria Mamma',
#   'https://www.yelp.com/biz/osteria-mamma-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1386 reviews',
#   '$$',
#   'Italian, Wine Bars'],
#  ['27. Myungrang Hot Dog-California Market LA',
#   'https://www.yelp.com/biz/myungrang-hot-dog-california-market-la-los-angeles?osq=restaurants',
#   '4 star rating',
#   '43 reviews',
#   'N/A',
#   'Hot Dogs'],
#  ['28. Hangari Bajirak Kalguksu',
#   'https://www.yelp.com/biz/hangari-bajirak-kalguksu-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1296 reviews',
#   '$$',
#   'Korean, Soup, Noodles'],
#  ['29. L’Assiette Steak Frites',
#   'https://www.yelp.com/biz/l-assiette-steak-frites-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '623 reviews',
#   '$$',
#   'Steakhouses, French, Wine Bars'],
#  ['30. Franco’s',
#   'https://www.yelp.com/biz/francos-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1094 reviews',
#   '$$',
#   'Italian, Steakhouses, Seafood']]

# %%
# #result list가지고 title을 key, 나머지를 value로 하는 result dict 만들기

# def get_restaurant_dict():
#     result_dict = {}
#     result_list = get_restaurant_list()
    
#     for item in result_list:
#         result_dict[item[0]] = (item[1], item[2], item[3], item[4], item[5])

# %%
#result를 dict로 만들기
def get_restaurant():
    result = {}
   
    r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
    restaurants = ch_driver.find_elements_by_xpath(r_path)
    for i,item in enumerate(restaurants):
        title = item.find_element_by_tag_name('h3').text
        link = item.find_element_by_tag_name('a').get_attribute('href')

        #get rating
        rating_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                      str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div')
        rating = rating_elem.get_attribute('aria-label')
        #print(rating)

        #get number of reviews
        review_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li['
                                                      + str(i+1)+']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span')
        review_num = review_elem.text

        #get price index and category
        try:
            pc_elem = ch_driver.find_elements_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                       str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
            price = pc_elem[0].text
            category = pc_elem[1].text
        except IndexError:
            pc_elem = ch_driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[' +
                                                       str(i+1) + ']/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[4]/span')
            price = "N/A"
            category = pc_elem.text
        
        #전체 var 받은뒤 title로 광고 게시물 거르기
        if title[0].isdigit() == False:
            continue
            
        result[title] = (link, rating, review_num, price, category)
    
 
        
    return result

# %%
get_restaurant()
# Out:
# {'1. Bestia': ('https://www.yelp.com/biz/bestia-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '5343 reviews',
#   '$$$',
#   'Italian, Cocktail Bars, Pizza'),
#  '2. Howlin’ Ray’s': ('https://www.yelp.com/biz/howlin-rays-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '4312 reviews',
#   '$$',
#   'Southern, Chicken Shop, American (Traditional)'),
#  '3. Running Goose': ('https://www.yelp.com/biz/running-goose-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '757 reviews',
#   '$$',
#   'Tapas/Small Plates, Gastropubs, Latin American'),
#  '4. République': ('https://www.yelp.com/biz/r%C3%A9publique-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '4452 reviews',
#   '$$',
#   'French, Breakfast & Brunch, Cocktail Bars'),
#  '5. RockSugar Southeast Asian Kitchen': ('https://www.yelp.com/biz/rocksugar-southeast-asian-kitchen-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2177 reviews',
#   '$$',
#   'Indonesian, Vietnamese, Malaysian'),
#  '6. The Morrison': ('https://www.yelp.com/biz/the-morrison-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3897 reviews',
#   '$$',
#   'Gastropubs, Burgers, Bars'),
#  '7. Slurpin’ Ramen Bar': ('https://www.yelp.com/biz/slurpin-ramen-bar-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '3172 reviews',
#   '$$',
#   'Ramen, Noodles'),
#  '8. Bao Dim Sum House': ('https://www.yelp.com/biz/bao-dim-sum-house-los-angeles?osq=restaurants',
#   '4 star rating',
#   '2402 reviews',
#   '$$',
#   'Dim Sum, Bars, Tapas/Small Plates'),
#  '9. Daikokuya Little Tokyo': ('https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?osq=restaurants',
#   '4 star rating',
#   '7858 reviews',
#   '$$',
#   'Ramen, Noodles'),
#  '10. Dirt Dog': ('https://www.yelp.com/biz/dirt-dog-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1511 reviews',
#   '$',
#   'Hot Dogs, Beer Bar'),
#  '11. Perch': ('https://www.yelp.com/biz/perch-los-angeles?osq=restaurants',
#   '4 star rating',
#   '6379 reviews',
#   '$$$',
#   'Lounges, French'),
#  '12. Yup Dduk La': ('https://www.yelp.com/biz/yup-dduk-la-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1761 reviews',
#   '$$',
#   'Korean'),
#  '13. Han Bat Shul Lung Tang': ('https://www.yelp.com/biz/han-bat-shul-lung-tang-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1906 reviews',
#   '$',
#   'Korean, Comfort Food, Soup'),
#  '14. Marugame Monzo': ('https://www.yelp.com/biz/marugame-monzo-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '3148 reviews',
#   '$$',
#   'Japanese, Noodles, Asian Fusion'),
#  '15. Genwa Korean BBQ': ('https://www.yelp.com/biz/genwa-korean-bbq-los-angeles-2?osq=restaurants',
#   '4.5 star rating',
#   '2652 reviews',
#   '$$',
#   'Korean, Barbeque, Soup'),
#  '16. Kang Ho-dong Baekjeong': ('https://www.yelp.com/biz/kang-ho-dong-baekjeong-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '3898 reviews',
#   '$$',
#   'Barbeque, Korean'),
#  '17. Eggslut': ('https://www.yelp.com/biz/eggslut-los-angeles-7?osq=restaurants',
#   '4 star rating',
#   '5263 reviews',
#   '$',
#   'Breakfast & Brunch'),
#  '18. Bottega Louie': ('https://www.yelp.com/biz/bottega-louie-los-angeles?osq=restaurants',
#   '4 star rating',
#   '15801 reviews',
#   '$$',
#   'Italian, Bakeries, Breakfast & Brunch'),
#  '19. Eataly': ('https://www.yelp.com/biz/eataly-los-angeles-6?osq=restaurants',
#   '3.5 star rating',
#   '1530 reviews',
#   '$$',
#   'Specialty Food, Italian, Food Court'),
#  '20. Pasta Sisters': ('https://www.yelp.com/biz/pasta-sisters-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1117 reviews',
#   '$$',
#   'Delis, Italian'),
#  '21. The Little Door': ('https://www.yelp.com/biz/the-little-door-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1918 reviews',
#   '$$$',
#   'French, Mediterranean, Modern European'),
#  '22. Dave’s Hot Chicken': ('https://www.yelp.com/biz/daves-hot-chicken-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1203 reviews',
#   '$$',
#   'Chicken Shop'),
#  '23. Corn Man': ('https://www.yelp.com/biz/corn-man-los-angeles-3?osq=restaurants',
#   '4.5 star rating',
#   '816 reviews',
#   '$',
#   'Food Stands, Mexican'),
#  '24. Wurstküche': ('https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '7913 reviews',
#   '$$',
#   'Hot Dogs, German, Gastropubs'),
#  '25. Sun Nong Dan': ('https://www.yelp.com/biz/sun-nong-dan-los-angeles-4?osq=restaurants',
#   '4.5 star rating',
#   '1163 reviews',
#   '$$',
#   'Korean, Soup'),
#  '26. Osteria Mamma': ('https://www.yelp.com/biz/osteria-mamma-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1386 reviews',
#   '$$',
#   'Italian, Wine Bars'),
#  '27. Myungrang Hot Dog-California Market LA': ('https://www.yelp.com/biz/myungrang-hot-dog-california-market-la-los-angeles?osq=restaurants',
#   '4 star rating',
#   '43 reviews',
#   'N/A',
#   'Hot Dogs'),
#  '28. Hangari Bajirak Kalguksu': ('https://www.yelp.com/biz/hangari-bajirak-kalguksu-los-angeles?osq=restaurants',
#   '4.5 star rating',
#   '1296 reviews',
#   '$$',
#   'Korean, Soup, Noodles'),
#  '29. L’Assiette Steak Frites': ('https://www.yelp.com/biz/l-assiette-steak-frites-los-angeles-2?osq=restaurants',
#   '4 star rating',
#   '623 reviews',
#   '$$',
#   'Steakhouses, French, Wine Bars'),
#  '30. Franco’s': ('https://www.yelp.com/biz/francos-los-angeles?osq=restaurants',
#   '4 star rating',
#   '1094 reviews',
#   '$$',
#   'Italian, Steakhouses, Seafood')}

# %% [markdown]
# ### 전체 정리
